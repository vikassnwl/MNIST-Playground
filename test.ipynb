# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from utils import center_digit

# %%
one = cv2.imread("image.jpg", 0)
plt.imshow(one, cmap="gray")

# %%
centered_image = center_digit(one)
plt.imshow(centered_image, cmap="gray")
